# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 40)

# %%
job_logs = pd.read_parquet('data/job_logs.parquet')

# %% [markdown]
# Sorting logs by identifier and log time.

# %%
job_logs = job_logs.set_index('Identifier').sort_values(by = ['Identifier','Time'], ascending = [False,True])

# %%
subset = job_logs[['CPU','Elapse']]

# %%
job_logs.tail(40)
# Out:
#                      Queue  STT    Memory       CPU   Elapse  Jobs  \
# Identifier
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# 0000e2fb93bf367f  clmedium  QUE   0.00000      0.00      0.0   1.0
# ...

# %% [markdown]
# Computing the difference in cumulative CPU and elapse time for every job. The first row of every job is deleted since no difference to previous logs can be computed.

# %%
subset_diff = subset.diff()
first_logs_per_job  = subset_diff.reset_index()['Identifier'].eq(subset_diff.reset_index()['Identifier'].shift()).values
subset_diff = subset_diff[first_logs_per_job]

# %%
subset_diff
# Out:
#                        CPU  Elapse
# Identifier
# ffffddf606283b7b      0.00     0.0
# ffff662620b8e573      0.00     0.0
# ffff662620b8e573      0.00     0.0
# ffff662620b8e573      0.00     0.0
# ffff662620b8e573      0.00     0.0
# ...                    ...     ...
# 0000e2fb93bf367f  20026.91   609.0
# 0000e2fb93bf367f -76285.36   606.0
# 000030ecd19c9c04      0.00     0.0
# 000030ecd19c9c04      0.00     0.0
# 000030ecd19c9c04     14.69    87.0
#
# [8829181 rows x 2 columns]

# %% [markdown]
# Instantaneous CPU load is estimated as `instantaneous_CPU_load` = `CPU.diff()` / `Elapse.diff()`

# %%
subset_diff['CPU_Load'] = subset_diff['CPU'] / subset_diff['Elapse']
instantaneous_CPU_load  = subset_diff[['CPU_Load']].fillna(0)

# %%
instantaneous_CPU_load
# Out:
#                     CPU_Load
# Identifier
# ffffddf606283b7b    0.000000
# ffff662620b8e573    0.000000
# ffff662620b8e573    0.000000
# ffff662620b8e573    0.000000
# ffff662620b8e573    0.000000
# ...                      ...
# 0000e2fb93bf367f   32.884910
# 0000e2fb93bf367f -125.883432
# 000030ecd19c9c04    0.000000
# 000030ecd19c9c04    0.000000
# 000030ecd19c9c04    0.168851
#
# [8829181 rows x 1 columns]

# %%
def quantile_diff(df, quantile = 0.05):
    '''
    This statistic to estimate an interactivity flag uses the difference of the outer quantiles given
    as the quantile argument. This difference is normalized to the maximum absolute value of the subset.
    Thereby all flags are values between 0 (not interactive) and 1 (very interactive).
    '''
    df          = df.reset_index()
    df_grouped  = df.groupby(['Identifier'])
    df_flag  = (df_grouped.quantile(1-quantile)-df_grouped.quantile(quantile))
    df_mean  = df_flag/df_grouped.mean()
    df_max   = df_flag/df_grouped.max()
    df_flag  = df_flag.rename(columns={'CPU_Load':'interactivity score'})
    df_mean  = df_mean.rename(columns={'CPU_Load':'normalized mean'})
    df_max   = df_max.rename(columns={'CPU_Load':'normalized max'})
    interactivity = pd.merge(df_flag, df_mean, left_index=True, right_index=True).merge(df_max, left_index=True, right_index=True)
    return(interactivity)

# %%
interactivity = quantile_diff(instantaneous_CPU_load)

# %%
interactivity
# Out:
#                   interactivity score  normalized mean  normalized max
# Identifier
# 000030ecd19c9c04             0.151966         2.700000        0.900000
# 0000e2fb93bf367f            39.535012       117.285097        1.193402
# 00020fcd04947084             0.000000         0.000000        0.000000
# 0002286e1d7e428d             0.004353         0.004375        0.004365
# 00027e89035bec8d            18.462994         3.400000        0.850000
# ...                               ...              ...             ...
# fffb2d67011101c5             4.089659        22.448665        1.974427
# fffd086716a4d46c             0.004373         0.004393        0.004382
# ffff38341e8c6b3b            31.907856         1.648952        0.953827
# ffff662620b8e573            18.321450        42.827236        1.109107
# ffffddf606283b7b             0.000000              NaN             NaN
#
# [85221 rows x 3 columns]

# %%
#interactivity.to_parquet('data/interactivity.parquet', compression='gzip')

# %%
job_chars = pd.read_parquet('data/job_chars.parquet')

# %% [markdown]
# Merging the job characteristic with the interactivity flag.

# %%
job_chars = pd.merge(job_chars, interactivity, left_index=True, right_index=True)

# %%
job_chars
# Out:
#                  Batch_class           Submission_date      Waited  \
# 000030ecd19c9c04       feque 2020-02-18 11:14:38+01:00   29.916667
# 00020fcd04947084    clexpres 2020-05-30 11:50:05+02:00    5.383333
# 0002286e1d7e428d    clmedium                       NaT         NaN
# 00027e89035bec8d    clmedium 2020-03-25 21:22:02+01:00   38.783333
# 0003a37a7a8562f1    clexpres 2020-03-06 11:52:11+01:00   70.450000
# ...                      ...                       ...         ...
# fffb2d67011101c5    clmedium                       NaT         NaN
# fffd086716a4d46c      cllong                       NaT         NaN
# ffff38341e8c6b3b    clmedium 2020-08-13 22:35:57+02:00  401.333333
# ffff662620b8e573    clmedium 2020-06-12 00:00:38+02:00   65.850000
# ffffddf606283b7b       feque 2020-02-18 15:32:52+01:00   10.966667
#
#                                 Start_date    Duration  Nodes        CPU  \
# 000030ecd19c9c04 2020-02-18 11:44:33+01:00    1.450000    1.0   0.168851
# ...

# %%
def grouping_cycle(df):
    df_new                  = df.reset_index()
    df_new['Weekday']       = df_new['Submission_date'].dt.day_name()
    df_new['Hour']          = df_new['Submission_date'].dt.hour
    weekday = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
    #Assign the above list to category ranking
    wDays = pd.api.types.CategoricalDtype(ordered= True, categories=weekday)
    #Apply this to the specific column in DataFrame
    df_new['Weekday'] = df_new['Weekday'].astype(wDays)
    return(df_new[['Waited','Batch_class','Weekday','Hour','normalized max']])

# %% [markdown]
# Adds columns of Weekday and hour to every job. Only waiting time, batch class, weekday, hour and the interactivity flag - normalized by the jobs maximum - are kept.

# %%
job_chars_cycle = grouping_cycle(job_chars)

# %%
mask = (job_chars_cycle['normalized max'] > 0.5) 
interactive_jobs = job_chars_cycle[mask]
noninteractive_jobs = job_chars_cycle[~mask]

# %%
def Barplot(interactive, non_interactive, batch_class, week = False):
    if week:
        column = 'Weekday'
        interactive_count = pd.DataFrame(interactive.loc[interactive['Batch_class'].str.contains(batch_class)].groupby('Weekday')['Batch_class'].agg('count')).reset_index()
        non_interactive_count = pd.DataFrame(non_interactive.loc[non_interactive['Batch_class'].str.contains(batch_class)].groupby('Weekday')['Batch_class'].agg('count')).reset_index()
    else:
        column = 'Hour'
        interactive_count = pd.DataFrame(interactive.loc[interactive['Batch_class'].str.contains(batch_class)].groupby('Hour')['Batch_class'].agg('count')).reset_index()
        non_interactive_count = pd.DataFrame(non_interactive.loc[non_interactive['Batch_class'].str.contains(batch_class)].groupby('Hour')['Batch_class'].agg('count')).reset_index()
    jobs = interactive_count.rename(columns={'Batch_class':'interactive'})
    jobs['not interactive'] = non_interactive_count['Batch_class']
    ax1 = jobs.set_index(column).plot.bar(figsize=(20,10),width=0.5,ylabel='Number of jobs',color=['midnightblue','darkred'],grid=True) 
    ax1.set_title(batch_class)
    return(jobs,column)

# %%
batch_classes = ['clexpres', 'clmedium', 'cllong', 'clbigmem', 'clfo2','feque']
for batch_class in batch_classes:
    Barplot(interactive_jobs, noninteractive_jobs, batch_class)

# %%
for batch_class in batch_classes:
    Barplot(interactive_jobs, noninteractive_jobs, batch_class, week = True)
