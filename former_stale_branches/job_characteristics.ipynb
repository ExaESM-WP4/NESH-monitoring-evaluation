# %% [markdown]
# # Job characteristics estimation
# Based on the post-processed log entries from the `job_logs_cleanup.ipynb` notebook, single job characteristics such as waiting time, job duration, and CPU and memory resource usage are estimated. Also, for each job the 95% range of logged CPU and memory resource usage is calculated, which might help to come up with a job interactivity score. These characteristics will not be statistically analysed here, but in follow-up Jupyter notebooks.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read cleaned-up job logs

# %%
job_logs = pd.read_parquet('job_logs.parquet')

# %%
job_logs
# Out:
#                Identifier     Queue  STT  Memory         CPU    Elapse  Jobs  \
# 0        50f38293dabf53e9  clbigmem  RUN   45.40    10000.86  560223.0   1.0
# 1        1cadd9af115874fc  clbigmem  RUN   66.43  1461501.36  181504.0   1.0
# 2        84b513a49a615a33  clbigmem  RUN   44.20  2973694.55   93235.0   1.0
# 3        817f139219e72642  clbigmem  RUN    2.01  1166604.28   36574.0   3.0
# 4        fc3ffa2fca1e77be  clbigmem  RUN   30.28   138055.86    4353.0   1.0
# ...                   ...       ...  ...     ...         ...       ...   ...
# 3785545  6cefcc4dd03175f4  clmedium  QUE    0.00        0.00       0.0   1.0
# 3785546  73d229aa76a5ae95  clmedium  QUE    0.00        0.00       0.0   1.0
# 3785547  3e84ada85baccae0  clmedium  QUE    0.00        0.00       0.0   1.0
# 3785548  638fe8e683508cfd  clmedium  QUE    0.00        0.00       0.0   1.0
# 3785549  fb53a1c6a768c160  clmedium  QUE    0.00        0.00       0.0   1.0
#
#                              Time                     Cycle
# 0       2020-02-06 19:53:11+01:00 2020-02-06 19:52:28+01:00
# 1       2020-02-06 19:53:11+01:00 2020-02-06 19:52:28+01:00
# 2       2020-02-06 19:53:11+01:00 2020-02-06 19:52:28+01:00
# 3       2020-02-06 19:53:11+01:00 2020-02-06 19:52:28+01:00
# 4       2020-02-06 19:53:11+01:00 2020-02-06 19:52:28+01:00
# ...                           ...                       ...
# 3785545 2020-06-04 09:11:32+02:00 2020-04-28 10:32:05+02:00
# 3785546 2020-06-04 09:11:32+02:00 2020-04-28 10:32:05+02:00
# 3785547 2020-06-04 09:11:32+02:00 2020-04-28 10:32:05+02:00
# 3785548 2020-06-04 09:11:32+02:00 2020-04-28 10:32:05+02:00
# 3785549 2020-06-04 09:11:32+02:00 2020-04-28 10:32:05+02:00
#
# [3785550 rows x 9 columns]

# %%
orig_log_length = job_logs.shape[0]

# %%
orig_unique_jobs = job_logs['Identifier'].unique().shape[0]

# %%
orig_log_length, orig_unique_jobs
# Out:
# (3785550, 79257)

# %% [markdown]
# ## Drop incompletely sampled jobs
# As waiting and run times, as well as CPU and memory resources cannot be accurately estimated for jobs that already existed at the beginning and the termination of a log cycle. This operation reduces the total job number close to the beginning and end of a log cycle, which should be kept in mind especially for time series analyses.

# %%
drop_these = job_logs.set_index('Time').loc[
    job_logs.groupby(['Cycle'])['Time'].min().to_list()
]['Identifier'].to_list()

# %%
drop_these = drop_these + job_logs.set_index('Time').loc[
    job_logs.groupby(['Cycle'])['Time'].max().to_list()
]['Identifier'].to_list()

# %%
job_logs = job_logs.set_index('Identifier').drop(index=drop_these).reset_index()

# %%
100*job_logs.shape[0]/orig_log_length, 100*job_logs['Identifier'].unique().shape[0]/orig_unique_jobs
# Out:
# (91.48417006775766, 97.82858296428076)

# %% [markdown]
# ## Drop jobs that don't report resources
# As we don't learn anything about these anyway.

# %%
subset = (job_logs.set_index('Identifier')['STT']=='RUN') & \
  job_logs.set_index('Identifier')['Elapse'].isna()

# %%
drop_these = job_logs.set_index('Identifier')[subset].index.unique()

# %%
with pd.option_context('display.max_rows', None):
    display(job_logs.set_index('Identifier').loc['75bc9d7758dce369'])
# Out:
#                      Queue  STT  Memory  CPU  Elapse  Jobs  \
# Identifier
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
# 75bc9d7758dce369  clexpres  RUN     NaN  NaN     NaN   1.0
#
#                                       Time                     Cycle
# Identifier
# 75bc9d7758dce369 2020-02-07 11:43:16+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 11:54:09+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 12:04:51+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 12:15:40+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 12:26:27+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 12:37:12+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 12:48:39+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 12:59:22+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 13:10:07+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 13:20:53+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 13:31:43+01:00 2020-02-06 19:52:28+01:00
# 75bc9d7758dce369 2020-02-07 13:42:43+01:00 2020-02-06 19:52:28+01:00

# %%
job_logs = job_logs.set_index('Identifier').drop(index=drop_these).reset_index()

# %%
100*job_logs.shape[0]/orig_log_length, 100*job_logs['Identifier'].unique().shape[0]/orig_unique_jobs
# Out:
# (91.18178336040998, 97.75540330822514)

# %% [markdown]
# ## Drop multi-queue jobs
#
# For jobs assigned to more than one batch class, the estimates that are calculated below won't be accurate. As there are not many multi-queue jobs (about 0.1% of the job entries), we simply decide to drop them for the job characteristics analysis.
#
# Note on user behaviour: Moving jobs to a different batch class needs manual user intervention with a specific batch scheduler command. Given the very low number of jobs with such a characteristic (but knowing that users likely move their jobs if they experience unacceptable waiting times), we can speculate that many users probably move their jobs to a different queue not by using the corresponding batch scheduler command, but rather by simply deleting and resubmitting a job. To keep the multi-queue jobs, we could split the job by the queue name and treat them as single jobs that never ran, and a job submitted at a later point that then might ran. However, previouly accumulated waiting time could have an influence on the job priority assigned by the scheduler and thus on the estimate waiting time, so this might not be correct to do. As already stated, these jobs are simply dropped for now.

# %%
batch_class_number = job_logs.groupby('Identifier')['Queue'].nunique()

# %%
drop_these = batch_class_number.index[batch_class_number > 1]

# %%
with pd.option_context('display.max_rows', None):
    display(job_logs.set_index('Identifier').loc['15f8e91ac6df1c5a'])
# Out:
#                      Queue  STT  Memory        CPU   Elapse  Jobs  \
# Identifier
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clmedium  QUE    0.00       0.00      0.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.03   11394.31    395.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.09   30555.84    995.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.11   49718.49   1596.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.13   68848.91   2197.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.14   88013.48   2798.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.15  107150.45   3399.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.16  126312.76   4000.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.17  145474.88   4603.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.18  164605.21   5203.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.18  183767.06   5807.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.19  202921.78   6408.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.19  222084.10   7009.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.20  242189.76   7616.0   4.0
# 15f8e91ac6df1c5a  clbigmem  RUN    2.20  261320.17   8217.0   4.0
# 15f8e91ac6df1c5a 2020-05-22 09:33:56+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 09:43:57+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 09:53:58+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 10:03:59+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 10:14:02+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 10:24:05+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 10:34:06+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 10:44:07+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 10:54:13+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 11:04:15+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 11:14:16+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 11:24:22+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 11:34:29+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 11:44:33+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 11:55:26+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 12:05:31+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 12:15:33+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 12:25:34+02:00 2020-04-28 10:32:05+02:00
# 15f8e91ac6df1c5a 2020-05-22 12:35:35+02:00 2020-04-28 10:32:05+02:00

# %%
job_logs = job_logs.set_index('Identifier').drop(index=drop_these).reset_index()

# %%
100*job_logs.shape[0]/orig_log_length, 100*job_logs['Identifier'].unique().shape[0]/orig_unique_jobs
# Out:
# (91.05844593255934, 97.71376660736591)

# %% [markdown]
# ## Post-processing of job states
#
# To accurately estimate job waiting and run times, we need to get rid of the job state discontinuities (for explanations on each job state see the sections below). Most of the job log entries are already either in a `QUE` or `RUN` state, and the goal here is come-up with continuous job log entries that have only `QUE` and `RUN` states, especially to simplify the accurate estimation of job waiting and run times later on.

# %%
100*job_logs['STT'].value_counts()/len(job_logs)
# Out:
# RUN    50.399485
# QUE    49.021587
# EXT     0.316095
# WAT     0.126281
# HLD     0.097329
# PRR     0.017145
# POR     0.014447
# STG     0.007630
# Name: STT, dtype: float64

# %% [markdown]
# ### `EXT` status
# About 0.9% of the jobs have exit status records. They might appear after a job's `RUN` period. There are no CPU/memory resource and elapse time records associated with these entries, so they will simply be dropped.

# %%
these_identifiers = job_logs[job_logs['STT']=='EXT']['Identifier'].unique()
100*these_identifiers.size/job_logs['Identifier'].unique().size
# Out:
# 0.8935373490864484

# %%
job_logs.set_index('Identifier').loc['7f18a64a9544028f']
# Out:
#                      Queue  STT  Memory        CPU   Elapse  Jobs  \
# Identifier
# 7f18a64a9544028f  clmedium  RUN    2.25    1926.07     64.0   1.0
# 7f18a64a9544028f  clmedium  RUN    6.89   21995.00    708.0   1.0
# 7f18a64a9544028f  clmedium  RUN    6.89   42002.19   1350.0   1.0
# 7f18a64a9544028f  clmedium  RUN    6.89   62970.65   1992.0   1.0
# 7f18a64a9544028f  clmedium  RUN    6.89   82924.17   2629.0   1.0
# ...                    ...  ...     ...        ...      ...   ...
# 7f18a64a9544028f  clmedium  RUN  149.72  340863.56  39224.0   1.0
# 7f18a64a9544028f  clmedium  RUN  149.46  360576.21  39845.0   1.0
# 7f18a64a9544028f  clmedium  RUN  149.37  379114.27  40464.0   1.0
# 7f18a64a9544028f  clmedium  RUN  149.22  398672.02  41084.0   1.0
# 7f18a64a9544028f  clmedium  EXT    0.00       0.00      0.0   1.0
#
#                                       Time                     Cycle
# Identifier
# 7f18a64a9544028f 2020-02-08 12:38:25+01:00 2020-02-06 19:52:28+01:00
# 7f18a64a9544028f 2020-02-08 12:49:09+01:00 2020-02-06 19:52:28+01:00
# 7f18a64a9544028f 2020-02-08 12:59:49+01:00 2020-02-06 19:52:28+01:00
# 7f18a64a9544028f 2020-02-08 13:10:32+01:00 2020-02-06 19:52:28+01:00
# 7f18a64a9544028f 2020-02-08 13:21:09+01:00 2020-02-06 19:52:28+01:00
# ...                                    ...                       ...
# 7f18a64a9544028f 2020-02-08 23:31:04+01:00 2020-02-06 19:52:28+01:00
# 7f18a64a9544028f 2020-02-08 23:41:25+01:00 2020-02-06 19:52:28+01:00
# 7f18a64a9544028f 2020-02-08 23:51:45+01:00 2020-02-06 19:52:28+01:00
# 7f18a64a9544028f 2020-02-09 00:02:05+01:00 2020-02-06 19:52:28+01:00
# 7f18a64a9544028f 2020-02-09 00:12:24+01:00 2020-02-06 19:52:28+01:00
#
# [68 rows x 8 columns]

# %% [markdown]
# ### `HLD` status
# About 0.2% of the jobs have hold status records.
#
# Considerations: Should these job log entries be removed? Should the whole jobs be removed, as they are not living only within the regular Linux cluster operation periods? Should all job logs in periods with non-regular Linux cluster operation be removed, as these indicate maintenance days?

# %%
these_identifiers = job_logs[job_logs['STT']=='HLD']['Identifier'].unique()
100*these_identifiers.size/job_logs['Identifier'].unique().size
# Out:
# 0.1911033636774485

# %%
job_logs[job_logs['STT']=='HLD'].set_index('Time')['Identifier'].resample('D').nunique().plot()
plt.grid(); plt.ylabel('jobs with HLD state')
# Out:
# Text(0, 0.5, 'jobs with HLD state')

# %%
job_logs.set_index('Identifier').loc['4993b9f181ffc499']
# Out:
#                      Queue  STT   Memory   CPU  Elapse  Jobs  \
# Identifier
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  HLD  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  QUE  0.00000   0.0     0.0   1.0
# 4993b9f181ffc499  clexpres  RUN  0.49072  47.7    50.0   1.0
#
#                                       Time                     Cycle
# Identifier
# 4993b9f181ffc499 2020-02-11 12:40:21+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 12:51:15+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 13:02:07+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 13:12:57+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 13:23:51+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 13:34:44+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 13:45:38+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 13:56:31+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 14:07:24+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 14:18:17+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 14:29:18+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 14:40:17+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 14:51:11+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 15:02:06+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 15:13:01+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 15:23:54+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 15:34:44+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 15:45:50+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 15:56:44+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 16:07:37+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 16:18:32+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 22:27:00+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 22:39:35+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 22:52:10+01:00 2020-02-06 19:52:28+01:00
# 4993b9f181ffc499 2020-02-11 23:04:57+01:00 2020-02-06 19:52:28+01:00

# %% [markdown]
# ### `POR` status
# About 0.6% of the jobs have post-running status records. There are memory and CPU resource information, as well as elapse time records available. The elapse time record might be used to more accurately estimate the job duration, we therefore simplify by assigning a `RUN` state to these job log entries.

# %%
these_identifiers = job_logs[job_logs['STT']=='POR']['Identifier'].unique()
100*these_identifiers.size/job_logs['Identifier'].unique().size
# Out:
# 0.6430369939957389

# %%
job_logs.set_index('Identifier').loc['e72bfd0bae1058bd']
# Out:
#                      Queue  STT   Memory        CPU  Elapse  Jobs  \
# Identifier
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  QUE  0.00000       0.00     0.0   4.0
# e72bfd0bae1058bd  clmedium  RUN  1.95000   18339.45   614.0   4.0
# e72bfd0bae1058bd  clmedium  RUN  1.96000   39417.97  1256.0   4.0
# e72bfd0bae1058bd  clmedium  RUN  1.98000   59537.98  1898.0   4.0
# e72bfd0bae1058bd  clmedium  RUN  1.99000   80584.77  2539.0   4.0
# e72bfd0bae1058bd  clmedium  RUN  2.00000  100705.72  3179.0   4.0
# e72bfd0bae1058bd  clmedium  RUN  2.01000  120825.48  3818.0   4.0
# e72bfd0bae1058bd  clmedium  RUN  2.01000  141872.21  4460.0   4.0
# e72bfd0bae1058bd  clmedium  RUN  2.02000  161996.53  5101.0   4.0
# %% [markdown]
# ### `PRR` status
# About 0.6% of the jobs have pre-running status records. This status appears at the transition from `QUE` to `RUN` state. No elapse time or CPU/memory resource information are available. This discontinuity should be taken into account for estimating the waiting time characteristics. To remove the discontinuity, we will manually assign the `QUE` status for these entries.

# %%
these_identifiers = job_logs[job_logs['STT']=='PRR']['Identifier'].unique()
100*these_identifiers.size/job_logs['Identifier'].unique().size
# Out:
# 0.5965523920201433

# %%
with pd.option_context('display.max_rows', None):
    display(job_logs.set_index('Identifier').loc['8a29b474b7002d06'])
# Out:
#                      Queue  STT  Memory        CPU  Elapse  Jobs  \
# Identifier
# 8a29b474b7002d06  clmedium  QUE    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  QUE    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  QUE    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  QUE    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  QUE    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  QUE    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  QUE    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  QUE    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  QUE    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  PRR    0.00       0.00     0.0   4.0
# 8a29b474b7002d06  clmedium  RUN    1.98   17785.62   600.0   4.0
# 8a29b474b7002d06  clmedium  RUN    2.00   36947.31  1201.0   4.0
# 8a29b474b7002d06  clmedium  RUN    2.01   56078.02  1802.0   4.0
# 8a29b474b7002d06  clmedium  RUN    2.02   75239.74  2403.0   4.0
# 8a29b474b7002d06  clmedium  RUN    2.03   94401.51  3004.0   4.0
# 8a29b474b7002d06  clmedium  RUN    2.04  113531.41  3605.0   4.0
# 8a29b474b7002d06  clmedium  RUN    2.04  132693.04  4206.0   4.0
# 8a29b474b7002d06  clmedium  RUN    2.05  151854.80  4806.0   4.0
# 8a29b474b7002d06  clmedium  RUN    2.06  171017.03  5407.0   4.0
# 8a29b474b7002d06  clmedium  RUN    2.07  190146.40  6008.0   4.0
#
#                                       Time                     Cycle
# Identifier
# 8a29b474b7002d06 2020-04-05 06:08:39+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 06:18:40+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 06:28:41+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 06:38:42+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 06:48:43+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 06:58:43+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 07:08:44+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 07:18:45+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 07:28:46+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 07:38:47+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 07:48:48+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 07:58:49+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 08:08:49+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 08:18:50+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 08:28:51+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 08:38:52+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 08:48:53+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 08:58:54+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 09:08:55+02:00 2020-03-03 11:32:54+01:00
# 8a29b474b7002d06 2020-04-05 09:18:55+02:00 2020-03-03 11:32:54+01:00

# %% [markdown]
# ### `STG` status
# About 0.3% of the jobs have staging status records. This status appears between the `QUE` and `RUN` state. No elapse time or CPU/memory resource information are available. The discontinuity should be taken into account for estimating the waiting time, though. For simplicity, we will manually assign the `QUE` state for these job log entries.

# %%
these_identifiers = job_logs[job_logs['STT']=='STG']['Identifier'].unique()
100*these_identifiers.size/job_logs['Identifier'].unique().size
# Out:
# 0.3395958422106011

# %%
job_logs.set_index('Identifier').loc['57fe9649cf6ede24']
# Out:
#                      Queue  STT  Memory        CPU  Elapse  Jobs  \
# Identifier
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  QUE    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  STG    0.00       0.00     0.0   4.0
# 57fe9649cf6ede24  clmedium  RUN    1.98   16556.06   590.0   4.0
# 57fe9649cf6ede24  clmedium  RUN    2.00   35717.83  1191.0   4.0
# 57fe9649cf6ede24  clmedium  RUN    2.01   54880.49  1792.0   4.0
# 57fe9649cf6ede24  clmedium  RUN    2.02   74014.12  2393.0   4.0
# 57fe9649cf6ede24  clmedium  RUN    2.03   93178.23  2994.0   4.0
100*these_identifiers.size/job_logs['Identifier'].unique().size
# Out:
# 0.10459035444509006

# %%
job_logs[job_logs['STT']=='WAT'].set_index('Time')['Identifier'].resample('D').nunique().plot()
plt.grid(); plt.ylabel('jobs with WAT state')
# Out:
# Text(0, 0.5, 'jobs with WAT state')

# %%
job_logs.set_index('Identifier').loc['0c270e0e2f5749a2']
# Out:
#                   Queue  STT   Memory      CPU   Elapse  Jobs  \
# Identifier
# 0c270e0e2f5749a2  clfo2  WAT  0.00000     0.00      0.0   1.0
# 0c270e0e2f5749a2  clfo2  WAT  0.00000     0.00      0.0   1.0
# 0c270e0e2f5749a2  clfo2  WAT  0.00000     0.00      0.0   1.0
# 0c270e0e2f5749a2  clfo2  WAT  0.00000     0.00      0.0   1.0
# 0c270e0e2f5749a2  clfo2  WAT  0.00000     0.00      0.0   1.0
# 0c270e0e2f5749a2  clfo2  WAT  0.00000     0.00      0.0   1.0
# 0c270e0e2f5749a2  clfo2  WAT  0.00000     0.00      0.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  1.01426   190.20    557.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  2.77000   481.10   1225.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  4.84000   570.06   1886.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  1.08000   352.96   2551.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  1.09000   443.43   3217.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  2.84000   570.35   3877.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  8.26000   842.99   4534.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  1.39000   813.03   5185.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  1.38000   862.46   5847.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  3.80000  1089.56   6503.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  2.77000  1116.43   7154.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  5.54000  1310.39   7805.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  4.71000  1275.34   8460.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  9.35000  1539.67   9138.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  0.71006  1240.90   9794.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  2.08000  1489.93  10455.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  5.88000  1688.56  11107.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  5.85000  1584.97  11764.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  5.30000  1687.04  12414.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  0.71013  1634.98  13068.0   1.0
# 0c270e0e2f5749a2  clfo2  RUN  1.39000  1846.51  13717.0   1.0
#
#                                       Time                     Cycle
# Identifier
# 0c270e0e2f5749a2 2020-02-13 13:22:36+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 13:33:33+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 13:44:32+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 13:55:34+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 14:06:35+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 14:17:42+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 14:28:38+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 14:39:35+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 14:50:42+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 15:01:43+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 15:12:48+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 15:23:54+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 15:34:54+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 15:45:51+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 15:56:42+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 16:07:44+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 16:18:41+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 16:29:31+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 16:40:23+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 16:51:18+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 17:02:35+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 17:13:32+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 17:24:32+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 17:35:24+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 17:46:21+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 17:57:11+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 18:08:05+01:00 2020-02-06 19:52:28+01:00
# 0c270e0e2f5749a2 2020-02-13 18:18:55+01:00 2020-02-06 19:52:28+01:00

# %% [markdown]
# ### Apply the post-processing

# %%
job_logs.replace(to_replace='PRR', value='QUE', inplace=True)

# %%
job_logs.replace(to_replace='STG', value='QUE', inplace=True)

# %%
job_logs.replace(to_replace='POR', value='RUN', inplace=True)

# %%
drop_these = job_logs['STT']=='EXT'
job_logs.drop(job_logs.index[drop_these], inplace=True)

# %% [markdown]
# Check if only `QUE` and `RUN` states are left. (There won't.)

# %%
100*job_logs['STT'].value_counts()/len(job_logs)
# Out:
# RUN    50.573793
# QUE    49.201887
# WAT     0.126682
# HLD     0.097638
# Name: STT, dtype: float64

# %% [markdown]
# For now, remove only the `HLD` and `WAT` states from the jobs. (But see considerations at `HLD` job states.)

# %%
drop_these = (job_logs.set_index('Identifier')['STT']=='HLD').index

# %%
drop_these = job_logs['STT']=='HLD'
job_logs.drop(job_logs.index[drop_these], inplace=True)

# %%
drop_these = job_logs['STT']=='WAT'
job_logs.drop(job_logs.index[drop_these], inplace=True)

# %%
100*job_logs['STT'].value_counts()/len(job_logs)
# Out:
# RUN    50.687495
# QUE    49.312505
# Name: STT, dtype: float64

# %%
100*job_logs.shape[0]/orig_log_length, 100*job_logs['Identifier'].unique().shape[0]/orig_unique_jobs
# Out:
# (90.56699819048751, 97.3402980178407)

# %% [markdown]
# ## Sampling error estimate
# The sampling error is estimated based on those 29.1% of the jobs for which a transition from `QUE` into `RUN` state was recorded. It is on average 5:11 minutes, i.e. a little bit less than about half of the average log sampling interval. This value might be taken as estimate for the systematic underestimation of job waiting and processing times as calculated below.

# %%
100*((job_logs.groupby('Identifier')['STT'].value_counts().unstack()>0).sum(axis=1)>1).sum() \
   / job_logs['Identifier'].unique().shape[0]
# Out:
# 29.068426032741836

# %%
grouped_que = job_logs[job_logs['STT']=='QUE'].groupby('Identifier')
grouped_run = job_logs[job_logs['STT']=='RUN'].groupby('Identifier')
sampling_bias = grouped_run['Time'].min() \
  - grouped_que['Time'].max() - pd.to_timedelta(grouped_run['Elapse'].min(), unit='s')

# %%
print(sampling_bias.mean())
# Out:
# 0 days 00:05:11.413270

# %%
(sampling_bias.dt.total_seconds()/60).hist(bins=np.arange(-0.5,14,1))
plt.xlabel('Sampling error in minutes')
# Out:
# Text(0.5, 0, 'Sampling error in minutes')

# %% [markdown]
# ### Actual log sampling interval
# Control of the log sampling is realised via a `sleep 10m` command. A drift might be caused by having implemented triggering of log records based on this approach. Also, because job logs are captured with Python and loading of the necessary software environment takes time, the actual log sampling interval might be larger. Indeed it is on average about 12:18 minutes.

# %%
sampling_interval = pd.Series(job_logs['Time'].unique()).diff()
print(sampling_interval.mean())
# Out:
# 0 days 00:12:18.263286

# %%
sampling_interval.dt.total_seconds().div(60).hist(bins=np.arange(9.5,20,1))
plt.yscale('log'); plt.xlabel('actual sampling interval in minutes')
# Out:
# Text(0.5, 0, 'actual sampling interval in minutes')

# %% [markdown]
# ## Job characteristics

# %% [markdown]
# ### Batch class

# %%
job_batch_class = job_logs.groupby('Identifier')['Queue'].unique()

# %%
job_batch_class = job_batch_class.apply(lambda x: x[0])

# %% [markdown]
# ### Submit date
# This is a biased quantity. Taken as first appearance of a job in the logs. There is no straightforward way of correcting it. Because of that, waiting times will be systematically underestimated.

# %%
grouped_que = job_logs[job_logs['STT']=='QUE'].groupby('Identifier')
job_submission_date = grouped_que['Time'].min()

# %% [markdown]
# ### Starting date
# Also biased, but a correction based on the elapse time record can be applied.

# %%
grouped_run = job_logs[job_logs['STT']=='RUN'].groupby('Identifier')
sampling_error = pd.to_timedelta(grouped_run['Elapse'].min(), unit='s')
job_start_date = grouped_run['Time'].min()-sampling_error

# %% [markdown]
# #### Starting date sampling error

# %%
sampling_error.dt.total_seconds().div(60).hist(bins=np.arange(-0.5,14,1))
plt.xlabel('Sampling error in minutes')
# Out:
# Text(0.5, 0, 'Sampling error in minutes')

# %% [markdown]
# ### Waiting time
# The most accurate estimate can be obtained based on the job submit and job start date estimated above. Not for all jobs a run period was detected, though. For these jobs waiting times can still be estimated from the start and end date associated with a job's waiting period. The error of this estimate might be twice the error of the date-based estimate though, as uncorrected sampling errors occur both at the beginning and end of the waiting period. Apparently, for about 25.9% of the jobs no waiting times are detected at all.

# %%
job_waited = (job_start_date-job_submission_date).dt.total_seconds()/60

# %%
100*job_waited.isna().value_counts()/job_waited.size
# Out:
# True     70.931574
# False    29.068426
# dtype: float64

# %%
grouped_que = job_logs[job_logs['STT']=='QUE'].groupby('Identifier')
job_waited_no_run = grouped_que['Time'].max()-grouped_que['Time'].min()
job_waited_no_run = job_waited_no_run.dt.total_seconds()/60

# %%
job_waited.fillna(value=job_waited_no_run, inplace=True)

# %%
100*job_waited.isna().value_counts()/job_waited.size
# Out:
# False    74.059288
# True     25.940712
# dtype: float64

# %% [markdown]
# ### Duration
# Note, due to sampling errors, there is a systematic underestimation for the job duration estimate as well.

# %%
grouped = job_logs[job_logs['STT']=='RUN'].groupby('Identifier')
job_duration = grouped['Elapse'].max()/60 # in minutes

# %% [markdown]
# ### CPU and memory resources

# %%
job_logs['CPU_occ'] = job_logs['CPU']/job_logs['Elapse']
grouped = job_logs[job_logs['STT']=='RUN'].groupby('Identifier')

# %%
job_cpu = grouped['CPU_occ'].max()

# %%
job_cpu_range = grouped['CPU_occ'].quantile([0.025, 0.975]).unstack().diff(axis=1) \
    .rename({0.975:'delta_CPU'}, axis='columns').drop(columns=0.025)

# %%
job_memory = grouped['Memory'].max()

# %%
job_memory_range = grouped['Memory'].quantile([0.025, 0.975]).unstack().diff(axis=1) \
    .rename({0.975:'delta_Memory'}, axis='columns').drop(columns=0.025)

# %% [markdown]
# ### Nodes per job

# %%
job_nodes = job_logs.groupby('Identifier')['Jobs'].mean()

# %% [markdown]
# ## Construct dataframe

# %%
derived_data = {'Batch_class': job_batch_class,
                'Submission_date': job_submission_date,
                'Waited': job_waited,
                'Start_date': job_start_date,
                'Duration': job_duration,
                'Nodes': job_nodes,
                'CPU': job_cpu,
                'Memory': job_memory,
                }

# %%
job_chars = pd.DataFrame(data=derived_data)

# %%
job_chars = pd.concat([job_chars, job_cpu_range, job_memory_range], axis=1)

# %%
job_chars
# Out:
#                  Batch_class           Submission_date       Waited  \
# 000030ecd19c9c04       feque 2020-02-18 11:14:38+01:00    29.916667
# 00020fcd04947084    clexpres 2020-05-30 11:50:05+02:00     5.383333
# 00027e89035bec8d    clmedium 2020-03-25 21:22:02+01:00    38.783333
# 0003a37a7a8562f1    clexpres 2020-03-06 11:52:11+01:00    70.450000
# 00040700e386e4c9       clfo2                       NaT          NaN
# ...                      ...                       ...          ...
# fff9d98fe020471f    clmedium 2020-02-29 14:20:38+01:00  1187.316667
# fffabf82e38ce12d    clmedium 2020-03-11 14:13:06+01:00  1763.016667
# fffb2d67011101c5    clmedium                       NaT          NaN
# fffbfaccf8c9fbf4    clexpres                       NaT          NaN
# ffffddf606283b7b       feque 2020-02-18 15:32:52+01:00    10.966667
#
#                                 Start_date     Duration  Nodes        CPU  \
# 000030ecd19c9c04 2020-02-18 11:44:33+01:00     1.450000    1.0   0.168851
# 00020fcd04947084 2020-05-30 11:55:28+02:00     4.700000    2.0  31.315993
# 00027e89035bec8d 2020-03-25 22:00:49+01:00     1.283333    1.0  21.721169
# 0003a37a7a8562f1                       NaT          NaN    1.0        NaN
# 00040700e386e4c9 2020-02-07 08:27:49+01:00    33.716667    8.0  23.732037
# ...                                    ...          ...    ...        ...
# fff9d98fe020471f 2020-03-01 10:07:57+01:00   104.850000    4.0  31.681539
# fffabf82e38ce12d 2020-03-12 19:36:07+01:00  1802.366667    1.0  31.920809
# fffb2d67011101c5 2020-03-18 20:23:17+01:00   117.633333    1.0   1.099404
# fffbfaccf8c9fbf4 2020-03-27 15:05:44+01:00     5.033333    1.0   0.190265
# ffffddf606283b7b                       NaT          NaN    1.0        NaN
#
#                      Memory  delta_CPU  delta_Memory
# 000030ecd19c9c04    0.31349   0.000000      0.000000
# 00020fcd04947084    2.02000   0.000000      0.000000
# 00027e89035bec8d  131.76000   0.000000      0.000000
# 0003a37a7a8562f1        NaN        NaN           NaN
# 00040700e386e4c9    1.42000   9.111494      0.066250
# ...                     ...        ...           ...
# fff9d98fe020471f    2.07000   5.921512      0.110000
# fffabf82e38ce12d    1.90000   0.151690      0.035250
# fffb2d67011101c5    1.46000   0.964377      1.191159
# fffbfaccf8c9fbf4    0.11484   0.000000      0.000000
# ffffddf606283b7b        NaN        NaN           NaN
#
# [77149 rows x 10 columns]

# %% [markdown]
# ## Manual corrections

# %%
correct_dates = (job_chars['Submission_date']<=job_chars['Start_date']) \
   | job_chars['Submission_date'].isna() | job_chars['Start_date'].isna()

# %%
correct_dates.value_counts()
# Out:
# True    77149
# dtype: int64

# %%
job_chars[job_chars['Waited']<0]['Submission_date']-sampling_bias_correction
# Out:
# Series([], Name: Submission_date, dtype: datetime64[ns, Europe/Berlin])

# %%
job_chars[job_chars['Waited']<0]
# Out:
#                  Batch_class           Submission_date    Waited  \
# 452d3bf73f74fdc7       clfo2 2020-02-17 21:47:58+01:00 -0.033333
# 6940fa7dd90857a1      cllong 2020-05-28 23:25:10+02:00 -1.766667
#
#                                 Start_date   Duration  Nodes       CPU  \
# 452d3bf73f74fdc7 2020-02-17 21:47:56+01:00  10.116667    1.0  0.631005
# 6940fa7dd90857a1 2020-05-28 23:23:24+02:00  40.966667    1.0  0.983763
#
#                     Memory  delta_CPU  delta_Memory
# 452d3bf73f74fdc7  15.61000   0.000000      0.000000
# 6940fa7dd90857a1   0.14954   0.029739      0.009917

# %%
job_chars['Waited'].min(),job_chars['Waited'].max(),job_chars['Waited'].isna().sum()

# %%
job_chars['Duration'].min(),job_chars['Duration'].max(),job_chars['Duration'].isna().sum()

# %% [markdown]
# ## Store on disk

# %%
job_chars.to_parquet('job_chars.parquet', compression='gzip')

# %%
job_chars

# %% [markdown]
# ## Appendix

# %%
# !conda list --explicit
